# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %%
print(pd.__name__)
# Out:
# pandas

# %%
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
countries
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries = pd.Series(
    ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан']
)
display(countries)
# Out:
# 0       Англия
# 1       Канада
# 2          США
# 3       Россия
# 4      Украина
# 5     Беларусь
# 6    Казахстан
# dtype: object

# %%
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
print(countries.loc['US'])
# США
# Out:
# США

# %%
print(countries.loc[['US', 'RU', 'UK']])
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
print(countries.iloc[6])
# Казахстан
# Out:
# Казахстан

# %%
countries.iloc[1:4]
# Out:
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object

# %%
countries[['UK', 'US', 'UA']]
# Out:
# UK     Англия
# US        США
# UA    Украина
# Name: countries, dtype: object

# %%
countries[[0, 2, 4]]
# Out:
# UK     Англия
# US        США
# UA    Украина
# Name: countries, dtype: object

# %%
def create_medications(names, counts):
    medications = pd.Series(
    data = counts,
    index = names,
    name = 'medication'
    )
    return medications

# %%
names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]

# %%
create_medications(names, counts)
# Out:
# chlorhexidine    15
# cyntomycin       18
# afobazol          7
# Name: medication, dtype: int64

# %%
def get_percent(medications, name):
    return(medications.loc[name]/sum(medications) * 100)

# %%
medications = create_medications(names, counts)
print(get_percent(medications, "chlorhexidine")) #37.5
# Out:
# 37.5

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

# %%
countries_df
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %% [markdown]
# При работе с Pandas важно уметь указывать направление работы метода, который используется. Для этого вводится понятие axis (ось, координата). Движение по строкам в таблице обозначается axis с индексом 0, а движение по столбцам — axis с индексом 1.
#
# Данный параметр заложен во все методы, которые могут работать в двух направлениях и по умолчанию в большинстве из них axis=0, то есть они выполняют операции со строками, если не задавать axis вручную.

# %%
countries_df.mean(axis=0)
# Out:
# population    9.070000e+01
# square        5.800860e+06
# dtype: float64

# %%
countries_df.mean(axis=1)
# Out:
# UK      66726.145
# CA    4992354.025
# US    4913476.140
# RU    8562668.620
# UA     301836.750
# BY     103804.750
# KZ    1362459.520
# dtype: float64

# %%
countries_df.population
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
countries_df['population']
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
type(countries_df.population)
# Out:
# pandas.core.series.Series

# %%
countries_df.loc['UK', 'square']
# Out:
# 133396

# %%
countries_df.iloc[0, 2]
# Out:
# 133396

# %%
countries_df.loc['RU', ['population', 'square']]
# Out:
# population      146.24
# square        17125191
# Name: RU, dtype: object

# %%
countries_df.loc[['UA', 'BY', 'KZ'],['population', 'square']]
# Out:
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902

# %%
countries_df.iloc[4:8, 1:3]
# Out:
#     population   square
# UA       45.50   603628
# BY        9.50   207600
# KZ       17.04  2724902

# %%
pd.DataFrame([[0,1], [1, 0]], columns=['А', 'B'])
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
pd.DataFrame({'А': [0, 1], 'B': [1, 0]})
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
def create_companyDF(income, expenses, years):
    """
    Создайте функцию create_companyDF(income, expenses, years), которая  возвращает DataFrame, 
    составленный из входных данных со столбцами “Income” и “Expenses” и индексами, соответствующим годам рассматриваемого периода.
    """
    df = pd.DataFrame({
    'Income': income,
    'Expenses': expenses,
    },
    index = years)
    return df

# %%
income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]
create_companyDF(income, expenses, years)
# Out:
#       Income  Expenses
# 2018     478       156
# 2019     512       130
# 2020     196       270

# %%
def get_profit(df, year):
    if year in df.index:
        profit = df.loc[year, 'Income'] - df.loc[year, 'Expenses']
    else:
        profit=None
    return profit

# %%
scienceyou = create_companyDF(income, expenses, years)
print(get_profit(scienceyou, 2020))
# Out:
# -74

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_excel('data/countries.xlsx', index=False)

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';')
display(countries_data)
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
countries_data_1 = pd.read_excel('data/countries.xlsx')
display(countries_data_1)
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 0          S      Biggin   3/12/2016       2.5  ...       1.0  1.0     202.0
# 1          S      Biggin   4/02/2016       2.5  ...       1.0  0.0     156.0
# 2         SP      Biggin   4/03/2017       2.5  ...       2.0  0.0     134.0
# 3         PI      Biggin   4/03/2017       2.5  ...       2.0  1.0      94.0
# 4         VB      Nelson   4/06/2016       2.5  ...       1.0  2.0     120.0
# ...      ...         ...         ...       ...  ...       ...  ...       ...
# 18391     SP        Greg  26/08/2017       6.8  ...       2.0  1.0       NaN
# 18392     PI     Sweeney  26/08/2017       6.8  ...       1.0  5.0     866.0
# 18393      S  Buckingham  26/08/2017      12.7  ...       3.0  2.0       NaN
# 18394     SP     Village  26/08/2017       6.3  ...       1.0  1.0     362.0
# 18395     VB     Village  26/08/2017       6.3  ...       2.0  2.0       NaN
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# 0               NaN        NaN        Yarra  -37.79960  144.99840
# 1              79.0     1900.0        Yarra  -37.80790  144.99340
# 2             150.0     1900.0        Yarra  -37.80930  144.99440
# 3               NaN        NaN        Yarra  -37.79690  144.99690
# 4             142.0     2014.0        Yarra  -37.80720  144.99410
# ...             ...        ...          ...        ...        ...
# 18391          89.0     2010.0          NaN  -37.86393  144.90484
# 18392         157.0     1920.0          NaN  -37.85908  144.89299
# 18393           NaN        NaN          NaN  -37.72006  145.10547
# 18394         112.0     1920.0          NaN  -37.81188  144.88449
# 18395         139.0     1950.0          NaN  -37.81829  144.87404
#
#                   Regionname  Propertycount
# 0      Northern Metropolitan         4019.0
# 1      Northern Metropolitan         4019.0
# 2      Northern Metropolitan         4019.0
# 3      Northern Metropolitan         4019.0
# 4      Northern Metropolitan         4019.0
# ...                      ...            ...
# 18391   Western Metropolitan         6380.0
# 18392   Western Metropolitan         6380.0
# 18393  Northern Metropolitan         1369.0
# 18394   Western Metropolitan         6543.0
# 18395   Western Metropolitan         6543.0
#
# [18396 rows x 22 columns]

# %%
data.to_csv('data/data.csv', index=False, sep=';')

# %%
data.to_excel('data/data.xlsx', index=False)

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')

# %%
melb_data
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
melb_data.loc[15,'Price']
# Out:
# 1310000.0

# %%
melb_data.loc[90,'Date']
# Out:
# '10/09/2016'

# %%
melb_data.loc[3521,'Landsize']/melb_data.loc[1690,'Landsize']
# Out:
# 2.7857142857142856

# %%
display(melb_data.head())
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
melb_data.tail(7)
# Out:
#               Suburb        Address  Rooms Type      Price Method  \
# 13573       Werribee    5 Nuragi Ct      4    h   635000.0      S
# 13574    Westmeadows     9 Black St      3    h   582000.0      S
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown    83 Power St      3    h  1170000.0      S
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 13573  hockingstuart  26/08/2017      14.7    3030.0  ...       2.0  1.0
# 13574            Red  26/08/2017      16.5    3049.0  ...       2.0  2.0
# 13575          Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0
# 13576       Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0
# 13577          Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0
# 13578        Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0
# 13579        Village  26/08/2017       6.3    3013.0  ...       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 13573     662.0         172.0     1980.0          NaN -37.89327   144.64789
# 13574     256.0           NaN        NaN          NaN -37.67917   144.89390
# 13575     652.0           NaN     1981.0          NaN -37.90562   145.16761
# 13576     333.0         133.0     1995.0          NaN -37.85927   144.87904
# 13577     436.0           NaN     1997.0          NaN -37.85274   144.88738
# 13578     866.0         157.0     1920.0          NaN -37.85908   144.89299
# 13579     362.0         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 13573        Western Metropolitan       16166.0
# 13574       Northern Metropolitan        2474.0
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [7 rows x 21 columns]

# %%
melb_data.shape
# Out:
# (13580, 21)

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB

# %%
melb_data=melb_data.fillna(0)

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom2'] = melb_data['Bedroom2'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  int64
#  16  CouncilArea    13580 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  int64
# dtypes: float64(7), int64(6), object(8)
# memory usage: 2.2+ MB

# %%
display(melb_data.head())
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...         1    1     202.0           0.0
# 1  4/02/2016       2.5    3067.0  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...         2    1      94.0           0.0
# 4  4/06/2016       2.5    3067.0  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0          0        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1       1900        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2       1900        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3          0        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4       2014        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0          4019
# 1          4019
# 2          4019
# 3          4019
# 4          4019
#
# [5 rows x 21 columns]

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776     79.788611  1.075684e+06
# std        5.868725    399.281619  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000      0.000000  6.500000e+05
# 50%        9.200000     51.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb        Address   Type Method SellerG        Date  \
# count       13580          13580  13580  13580   13580       13580
# unique        314          13378      3      5     268          58
# top     Reservoir  53 William St      h      S  Nelson  27/05/2017
# freq          359              3   9449   9022    1565         473
#
#         CouncilArea             Regionname
# count         13580                  13580
# unique           34                      8
# top               0  Southern Metropolitan
# freq           1369                   4695

# %%
melb_data['Regionname'].value_counts()
# Out:
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: Regionname, dtype: int64

# %%
melb_data['Method'].value_counts()
# Out:
# S     9022
# SP    1703
# PI    1564
# VB    1199
# SA      92
# Name: Method, dtype: int64

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: Regionname, dtype: float64

# %%
data = pd.DataFrame([[0,1], [1, 0], [1, 1]], columns=['А', 'B'])

# %%
melb_data['Type'].value_counts(normalize=True)
# Out:
# h    0.695803
# u    0.222165
# t    0.082032
# Name: Type, dtype: float64

# %%
print(melb_data['Price'].mean())
# Out:
# 1075684.079455081

# %%
print(melb_data['Car'].max())
# Out:
# 10

# %%
rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))
# Total income of real estate agencies: 1752934775.88
# Out:
# Total income of real estate agencies: 1752934775.88

# %%
landsize_median = melb_data['Landsize'].median() 
landsize_mean =  melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# 0.21205713983546193
# Out:
# 0.21205713983546193

# %%
print(melb_data['Rooms'].mode())
# 0    3
# dtype: int64
# Out:
# 0    3
# dtype: int64

# %%
melb_data['Regionname'].mode()
# Out:
# 0    Southern Metropolitan
# dtype: object

# %%
melb_data['Propertycount'].max()
# Out:
# 21650

# %%
round(melb_data['Distance'].std(),0)
# Out:
# 6.0

# %%
BuildingArea_median = melb_data['BuildingArea'].median() 
BuildingArea_mean =  melb_data['BuildingArea'].mean()
print((abs(BuildingArea_median - BuildingArea_mean)/BuildingArea_mean)*100)
# Out:
# 36.08110347662568

# %%
building_median = melb_data['BuildingArea'].median() 
building_mean =  melb_data['BuildingArea'].mean()
deviance = abs(building_median - building_mean)/building_mean
print(round(deviance * 100, 2))
# Out:
# 36.08

# %%
melb_data['Bedroom2'].mode()
# Out:
# 0    3
# dtype: int64

# %%
mask = melb_data['Price'] > 2000000
display(mask)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool

# %%
display(melb_data[mask].head())
# Out:
#          Suburb               Address  Rooms Type      Price Method   SellerG  \
# 80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI    Buxton
# 85  Albert Park     104 Richardson St      4    h  2300000.0      S  Marshall
# 88  Albert Park        29 Faussett St      2    h  2120000.0      S      Greg
# 92  Albert Park           2 Dundas Pl      3    h  2615000.0      S    Cayzer
# 93  Albert Park          23 Finlay St      5    h  2100000.0      S      Greg
#
#           Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 80   4/03/2017       3.3    3206.0  ...         2    0     211.0
# 85   7/05/2016       3.3    3206.0  ...         2    1     153.0
# 88  10/09/2016       3.3    3206.0  ...         1    1     199.0
# 92  10/12/2016       3.3    3206.0  ...         2    1     177.0
# 93  10/12/2016       3.3    3206.0  ...         2    1     237.0
#
#     BuildingArea  YearBuilt   CouncilArea Lattitude  Longtitude  \
# 80         198.0       1890  Port Phillip  -37.8481    144.9499
# 85         180.0       1880  Port Phillip  -37.8447    144.9523
# 88         107.0       1900  Port Phillip  -37.8422    144.9554
# 92         181.0       1880  Port Phillip  -37.8415    144.9585
# 93           0.0          0  Port Phillip  -37.8436    144.9557
#
#                Regionname Propertycount
# 80  Southern Metropolitan          3280
# 85  Southern Metropolitan          3280
# 88  Southern Metropolitan          3280
# 92  Southern Metropolitan          3280
# 93  Southern Metropolitan          3280
#
# [5 rows x 21 columns]

# %%
melb_data[melb_data['Price'] > 2000000]
# Out:
#                Suburb               Address  Rooms Type      Price Method  \
# 80        Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85        Albert Park     104 Richardson St      4    h  2300000.0      S
# 88        Albert Park        29 Faussett St      2    h  2120000.0      S
# 92        Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93        Albert Park          23 Finlay St      5    h  2100000.0      S
# ...               ...                   ...    ...  ...        ...    ...
# 13521  Port Melbourne          44 Garton St      4    t  2455000.0     SP
# 13523         Prahran        69 Greville St      4    h  2668000.0      S
# 13553    Surrey Hills          20 Albert Cr      4    h  2720000.0      S
# 13555    Surrey Hills              3 Oak St      4    h  3100000.0     VB
# 13578    Williamstown          96 Verdon St      4    h  2500000.0     PI
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 80       Buxton   4/03/2017       3.3    3206.0  ...         2    0     211.0
# 85     Marshall   7/05/2016       3.3    3206.0  ...         2    1     153.0
# 88         Greg  10/09/2016       3.3    3206.0  ...         1    1     199.0
# 92       Cayzer  10/12/2016       3.3    3206.0  ...         2    1     177.0
# 93         Greg  10/12/2016       3.3    3206.0  ...         2    1     237.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13521  Marshall  26/08/2017       3.5    3207.0  ...         3    2     123.0
# 13523    Biggin  26/08/2017       4.6    3181.0  ...         2    2     383.0
# 13553       Kay  26/08/2017      10.2    3127.0  ...         3    2    1005.0
# 13555  Marshall  26/08/2017      10.2    3127.0  ...         2    3     832.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...         1    5     866.0
#
#        BuildingArea  YearBuilt   CouncilArea Lattitude  Longtitude  \
# 80            198.0       1890  Port Phillip -37.84810   144.94990
# 85            180.0       1880  Port Phillip -37.84470   144.95230
# 88            107.0       1900  Port Phillip -37.84220   144.95540
# 92            181.0       1880  Port Phillip -37.84150   144.95850
# 93              0.0          0  Port Phillip -37.84360   144.95570
# ...             ...        ...           ...       ...         ...
# 13521           0.0       2010             0 -37.83349   144.94840
# 13523           0.0          0             0 -37.84879   144.98882
# 13553           0.0       1920             0 -37.82421   145.10352
# 13555           0.0          0             0 -37.83564   145.10919
# 13578         157.0       1920             0 -37.85908   144.89299
#
#                   Regionname Propertycount
# 80     Southern Metropolitan          3280
# 85     Southern Metropolitan          3280
# 88     Southern Metropolitan          3280
# 92     Southern Metropolitan          3280
# 93     Southern Metropolitan          3280
# ...                      ...           ...
# 13521  Southern Metropolitan          8648
# 13523  Southern Metropolitan          7717
# 13553  Southern Metropolitan          5457
# 13555  Southern Metropolitan          5457
# 13578   Western Metropolitan          6380
#
# [1007 rows x 21 columns]

# %%
melb_data[melb_data['Rooms'] == 3]['Rooms'].count()
# Out:
# 5881

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 3

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)]
# Out:
#               Suburb         Address  Rooms Type     Price Method  \
# 10394         Melton      14 Musk Ct      3    h  295000.0     SP
# 10576  Bacchus Marsh    4 Lidgett St      3    h  285000.0      S
# 13227         Melton  118 Barries Rd      3    h  283000.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 10394  PRDNationwide  27/05/2017      31.7    3337.0  ...         1    4
# 10576          Ryder   8/07/2017      37.5    3340.0  ...         1    2
# 13227             FN  23/09/2017      31.7    3337.0  ...         1    0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 10394     600.0        122.86       1975       Melton -37.68734   144.58001
# 10576     612.0          0.00          0    Moorabool -37.67344   144.43181
# 13227     362.0         19.00       1976            0 -37.68755   144.56887
#
#              Regionname Propertycount
# 10394  Western Victoria          3600
# 10576  Western Victoria          2871
# 13227  Western Victoria          3600
#
# [3 rows x 21 columns]

# %%
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 7

# %%
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)]
# Out:
#               Suburb              Address  Rooms Type     Price Method  \
# 1805       Caulfield           30 Pyne St      4    h  131000.0     PI
# 1927          Coburg      171 Moreland Rd      4    h  145000.0     PI
# 2455        Essendon  8/15 Shaftesbury St      1    u  250000.0     VB
# 2951         Glenroy           2/4 Ash Ct      2    h  270000.0     PI
# 10394         Melton           14 Musk Ct      3    h  295000.0     SP
# 10576  Bacchus Marsh         4 Lidgett St      3    h  285000.0      S
# 13227         Melton       118 Barries Rd      3    h  283000.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1805          Rodney  25/02/2017       8.9    3162.0  ...         1    2
# 1927          Jellis   4/06/2016       7.8    3058.0  ...         1    1
# 2455            Brad  27/06/2016       8.0    3040.0  ...         1    1
# 2951             Ray  30/07/2016      13.0    3046.0  ...         1    1
# 10394  PRDNationwide  27/05/2017      31.7    3337.0  ...         1    4
# 10576          Ryder   8/07/2017      37.5    3340.0  ...         1    2
# 13227             FN  23/09/2017      31.7    3337.0  ...         1    0
#
#        Landsize  BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# 1805      499.0        155.00       1920      Glen Eira -37.88640   145.02420
# 1927      536.0        164.00       1910       Moreland -37.75550   144.96580
# 2455        0.0        125.00       1970  Moonee Valley -37.75230   144.92210
# 2951      155.0        155.00       2000       Moreland -37.69720   144.92390
# 10394     600.0        122.86       1975         Melton -37.68734   144.58001
# 10576     612.0          0.00          0      Moorabool -37.67344   144.43181
# 13227     362.0         19.00       1976              0 -37.68755   144.56887
#
#                   Regionname Propertycount
# 1805   Southern Metropolitan          2379
# 1927   Northern Metropolitan         11204
# 2455    Western Metropolitan          9264
# 2951   Northern Metropolitan          8870
# 10394       Western Victoria          3600
# 10576       Western Victoria          2871
# 13227       Western Victoria          3600
#
# [7 rows x 21 columns]

# %%
melb_data[melb_data['Type'] == 't']['Rooms'].max()
# Out:
# 5

# %%
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# 85.5

# %%
melb_data[melb_data['Bathroom'] == 0].shape[0]
# Out:
# 34

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0]
# Out:
# 5

# %%
melb_data[melb_data['BuildingArea'] == 0].describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6467.000000  6.467000e+03  6467.000000  6467.000000  6467.000000
# mean      2.896088  1.071992e+06    10.138132  3106.299057     2.876759
# std       0.937101  5.990220e+05     5.695394    89.285703     0.959010
# min       1.000000  8.500000e+04     0.000000  3000.000000     0.000000
# 25%       2.000000  6.650000e+05     6.200000  3046.000000     2.000000
# 50%       3.000000  9.170000e+05     9.400000  3088.000000     3.000000
# 75%       3.000000  1.325250e+06    13.000000  3148.000000     3.000000
# max      10.000000  5.800000e+06    47.300000  3977.000000    20.000000
#
#           Bathroom          Car       Landsize  BuildingArea    YearBuilt  \
# count  6467.000000  6467.000000    6467.000000        6467.0  6467.000000
# mean      1.462657     1.601206     633.222360           0.0   414.915726
# std       0.651170     0.985238    5677.813984           0.0   802.751635
# min       0.000000     0.000000       0.000000           0.0     0.000000
# 25%       1.000000     1.000000     192.000000           0.0     0.000000
# 50%       1.000000     2.000000     479.000000           0.0     0.000000
# 75%       2.000000     2.000000     663.500000           0.0     0.000000
# max       8.000000    10.000000  433014.000000           0.0  2017.000000
#
#          Lattitude  Longtitude  Propertycount
# count  6467.000000  6467.00000    6467.000000
# mean    -37.810412   144.99925    7480.866708
# std       0.078375     0.10250    4413.213116
# min     -38.182550   144.43181     249.000000
# 25%     -37.856990   144.93518    4380.000000
# 50%     -37.802300   145.00390    6567.000000
# 75%     -37.755695   145.06045   10331.000000
# max     -37.500870   145.47052   21650.000000

# %%
melb_data[melb_data['BuildingArea'] == 0]['Price'].min()
# Out:
# 85000.0

# %%
melb_data[(melb_data['BuildingArea'] == 0)]['Price'].min()
# Out:
# 85000.0

# %%
round(melb_data[(melb_data['Price'] < 1000000) & 
          ((melb_data['Rooms'] > 5) | 
          (melb_data['YearBuilt'] > 2015))]['Price'].mean(),0)
# Out:
# 769239.0

# %%
melb_data[(melb_data['Price'] < 1000000) & 
          ((melb_data['Rooms'] > 5) | 
          (melb_data['YearBuilt'] > 2015))].tail()
# Out:
#                Suburb          Address  Rooms Type     Price Method SellerG  \
# 12618      Thomastown   274 Station St      6    h  931000.0      S     HAR
# 12629      Yarraville  28 Cranbrook St      3    h  826000.0     SP      RT
# 12728        Gisborne     7 Wyralla Cr      6    h  650000.0     SP   Raine
# 13226  Meadow Heights     13 Haddon Ct      8    h  741000.0      S   Barry
# 13437       Gowanbrae    24 Duranta Dr      4    t  655000.0      S  Nelson
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 12618   9/09/2017      15.3    3074.0  ...         3    3     646.0
# 12629   9/09/2017       6.3    3013.0  ...         2    2     492.0
# 12728  16/09/2017      45.9    3437.0  ...         2    2    1301.0
# 13226  23/09/2017      17.4    3048.0  ...         3    1    1063.0
# 13437  26/08/2017      12.9    3043.0  ...         3    2     170.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 12618           0.0          0            0 -37.67522   145.01554
# 12629           0.0       2017            0 -37.82413   144.87513
# 12728           0.0          0            0 -37.50733   144.58666
# 13226         101.0       1980            0 -37.65826   144.92538
# 13437         215.0       2017            0 -37.70128   144.90187
#
#                   Regionname Propertycount
# 12618  Northern Metropolitan          7955
# 12629   Western Metropolitan          6543
# 12728      Northern Victoria          3376
# 13226  Northern Metropolitan          4704
# 13437   Western Metropolitan          1071
#
# [5 rows x 21 columns]

# %%
melb_data[(melb_data['Type'] == 'h') & 
          (melb_data['Price'] < 3000000)].describe(include=['object'])
# Out:
#            Suburb     Address  Type Method SellerG        Date  CouncilArea  \
# count        9220        9220  9220   9220    9220        9220         9220
# unique        313        9075     1      5     232          58           34
# top     Reservoir  2 Bruce St     h      S  Nelson  27/05/2017            0
# freq          253           3  9220   6367    1154         334         1221
#
#                    Regionname
# count                    9220
# unique                      8
# top     Northern Metropolitan
# freq                     2737

# %%
melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# dtype: object
