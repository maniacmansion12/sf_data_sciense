# %%
import pandas as pd

# %%
ratings_movies = pd.read_csv('data/ratings_movies.csv')

# %%
ratings_movies
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)

# %%
len(ratings_movies['year_release'])
# Out:
# 100836

# %%
ratings_movies['year_release'].count()
# Out:
# 100818

# %%
(len(ratings_movies['year_release'])) - (ratings_movies['year_release'].count())
# Out:
# 18

# %%
mask_8_2 = ratings_movies['year_release'] == 1999

# %%
ratings_movies[mask_8_2].groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %%
ratings_movies[ratings_movies['year_release'] == 2010].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
ratings_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
ratings_movies.groupby('genres')['rating'].agg(['count', 'mean']).sort_values(['count', 'mean'], ascending=[True,False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
filter_2018 = ratings_movies[ratings_movies['year_release'] == 2018]

# %%
qwe = filter_2018.groupby('genres')['rating'].agg(['count', 'mean'])

# %%
qwe[qwe['count'] > 10]
# Out:
#                          count      mean
# genres
# Action|Adventure|Sci-Fi     14  3.928571
# Action|Comedy|Sci-Fi        12  3.875000

# %%
ratings_movies['year_rating'] = pd.to_datetime(ratings_movies['date'], dayfirst=False).dt.year

# %%
pivot=ratings_movies.pivot_table(
    index='year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)

# %%
pivot['Action|Adventure'].min()
# Out:
# 3.2777777777777777

# %%
pivot[pivot['Action|Adventure|Animation|Children|Comedy|IMAX'] == pivot['Action|Adventure|Animation|Children|Comedy|IMAX'].max()]
# Out:
# genres       (no genres listed)  Action  Action|Adventure  \
# year_rating
# 2013                        NaN     2.5          3.833333
#
# genres       Action|Adventure|Animation  Action|Adventure|Animation|Children  \
# year_rating
# 2013                                NaN                                  3.0
#
# genres       Action|Adventure|Animation|Children|Comedy  \
# year_rating
# 2013                                           4.333333
#
# genres       Action|Adventure|Animation|Children|Comedy|Fantasy  \
# year_rating
# 2013                                                       NaN
#
# genres       Action|Adventure|Animation|Children|Comedy|IMAX  \
# year_rating
# 2013                                                     5.0
#
# genres       Action|Adventure|Animation|Children|Comedy|Romance  \
# year_rating
# 2013                                                       NaN
#
# genres       Action|Adventure|Animation|Children|Comedy|Sci-Fi  ...  \
# ...

# %%
pivot.loc[2018].describe()
# Out:
# count    610.000000
# mean       3.261867
# std        0.864871
# min        0.500000
# 25%        2.853409
# 50%        3.418860
# 75%        3.821349
# max        5.000000
# Name: 2018, dtype: float64

# %%
orders = pd.read_csv('data/orders.csv',sep=';')

# %%
products = pd.read_csv('data/products.csv',sep=';')

# %%
products
# Out:
#     Product_ID                                   Name  Price CURRENCY
# 0           47                   Шатны Полосатый рейс   2999      RUR
# 1           51               Платье Аленький цветочек   4999      RUR
# 2           53                 Штаны Цветочная Поляна   4999      RUR
# 3           71                    Платье Ночная Жизнь   7999      RUR
# 4           74               Платье Ночная Жизнь XXXL   8999      RUR
# 5           86                     Носки Простые, муж     45      RUR
# 6           91                     Носки Честные, муж     50      RUR
# 7          103                  Носки Подарочные, муж    199      RUR
# 8          104                  Носки Подарочные, жен    249      RUR
# 9          124                   Носки беговые Camino    999      RUR
# 10         137              Гольфы детские Снегурочка     99      RUR
# 11         138               Гольфы детские Питер Пен     99      RUR
# ...

# %%
orders
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products = orders.merge(products,
                               left_on ='ID товара',
                               right_on='Product_ID',
                               how='left')

# %%
orders_products
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products[orders_products['Отменен'] == 'Да']['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %%
orders_products['Profit'] = orders_products['Price'] * orders_products['Количество'] 

orders_products[orders_products['Оплачен'] == 'Да'].groupby('ID Покупателя')['Profit'].sum().sort_values(ascending=False)
# Out:
# ID Покупателя
# 7    17096.0
# 5    13043.0
# 8     1344.0
# 1        0.0
# Name: Profit, dtype: float64
