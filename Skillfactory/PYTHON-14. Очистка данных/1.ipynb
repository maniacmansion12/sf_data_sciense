# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sber_data = pd.read_csv('sber_data.csv')
sber_data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# 2                               7                                      0  ...
# 3                              10                                      0  ...
# 4                               9                                      0  ...
#
#    office_km  additional_education_km  preschool_km  big_church_km  \
# 0   0.637189                 0.947962      0.177975       0.625783
# 1   0.688796                 1.072315      0.273345       0.967821
# 2   1.543049                 0.391957      0.158072       3.178751
# 3   0.934273                 0.892674      0.236455       1.031777
# 4   0.077901                 0.810801      0.376838       0.378756
#
#    church_synagogue_km  theater_km  museum_km    ecology mosque_count_1000  \
# 0             0.628187   14.053047   7.389498       good                 0
# 1             0.471447    6.829889   0.709260  excellent                 0
# 2             0.755946    4.273200   3.156423       poor                 0
# 3             1.561505   16.990677  16.041521       good                 0
# 4             0.121681    1.112486   1.800125  excellent                 0
#
#   price_doc
# 0   5850000
# 1   6000000
# 2   5700000
# 3  13100000
# 4  16331452
#
# [5 rows x 61 columns]

# %%
display(sber_data.tail())
# Out:
#           id  full_sq  life_sq  floor              sub_area  preschool_quota  \
# 30466  30469       44     27.0    7.0              Otradnoe           5088.0
# 30467  30470       86     59.0    3.0              Tverskoe           1874.0
# 30468  30471       45      NaN   10.0  Poselenie Vnukovskoe              NaN
# 30469  30472       64     32.0    5.0          Obruchevskoe           2372.0
# 30470  30473       43     28.0    1.0           Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# 30466                                  4       12721.0
# 30467                                  4        6772.0
# 30468                                  0           NaN
# 30469                                  6        6083.0
# 30470                                  4        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 30466                               4                                      0
# 30467                               4                                      1
# 30468                               0                                      0
# 30469                               8                                      0
# 30470                               4                                      0
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 30466  ...   1.103579                 0.167718      0.349899       1.235066
# 30467  ...   0.069986                 0.086552      0.362681       0.850385
# 30468  ...   4.338453                 1.339078      1.234235       1.192543
# 30469  ...   1.204798                 1.340017      0.130667       1.644053
# 30470  ...   2.108265                 0.825811      0.378950       0.480531
#
#        church_synagogue_km  theater_km  museum_km       ecology  \
# 30466             0.612359    7.482165   4.836787          good
# 30467             0.310021    0.778428   1.450108          poor
# 30468             1.186621   13.459593   9.890758       no data
# 30469             0.476021    2.088193   4.119706  satisfactory
# 30470             0.867332    0.688707   0.127867          poor
#
#       mosque_count_1000 price_doc
# 30466                 0   7400000
# 30467                 0  25000000
# 30468                 0   6970959
# 30469                 0  13500000
# 30470                 0   5600000
#
# [5 rows x 61 columns]

# %%
sber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     30471 non-null  int64
#  1   full_sq                                30471 non-null  int64
#  2   life_sq                                24088 non-null  float64
#  3   floor                                  30304 non-null  float64
#  4   sub_area                               30471 non-null  object
#  5   preschool_quota                        23783 non-null  float64
#  6   preschool_education_centers_raion      30471 non-null  int64
#  7   school_quota                           23786 non-null  float64
#  8   school_education_centers_raion         30471 non-null  int64
#  9   school_education_centers_top_20_raion  30471 non-null  int64
#  10  hospital_beds_raion                    16030 non-null  float64
#  11  healthcare_centers_raion               30471 non-null  int64
#  12  university_top_20_raion                30471 non-null  int64
#  13  sport_objects_raion                    30471 non-null  int64
#  14  additional_education_raion             30471 non-null  int64
#  15  culture_objects_top_25_raion           30471 non-null  int64
#  16  shopping_centers_raion                 30471 non-null  int64
#  17  office_raion                           30471 non-null  int64
#  18  oil_chemistry_raion                    30471 non-null  object
#  19  railroad_terminal_raion                30471 non-null  object
#  20  nuclear_reactor_raion                  30471 non-null  object
#  21  metro_min_avto                         30471 non-null  float64
#  22  metro_km_avto                          30471 non-null  float64
#  23  metro_min_walk                         30446 non-null  float64
#  24  metro_km_walk                          30446 non-null  float64
#  25  kindergarten_km                        30471 non-null  float64
#  26  school_km                              30471 non-null  float64
#  27  park_km                                30471 non-null  float64
#  28  green_zone_km                          30471 non-null  float64
#  29  industrial_km                          30471 non-null  float64
#  30  railroad_station_walk_km               30446 non-null  float64
#  31  railroad_station_walk_min              30446 non-null  float64
#  32  public_transport_station_km            30471 non-null  float64
#  33  public_transport_station_min_walk      30471 non-null  float64
#  34  mkad_km                                30471 non-null  float64
#  35  ttk_km                                 30471 non-null  float64
#  36  sadovoe_km                             30471 non-null  float64
#  37  bulvar_ring_km                         30471 non-null  float64
#  38  kremlin_km                             30471 non-null  float64
#  39  big_road1_1line                        30471 non-null  object
#  40  big_market_km                          30471 non-null  float64
#  41  market_shop_km                         30471 non-null  float64
#  42  fitness_km                             30471 non-null  float64
#  43  swim_pool_km                           30471 non-null  float64
#  44  ice_rink_km                            30471 non-null  float64
#  45  stadium_km                             30471 non-null  float64
#  46  basketball_km                          30471 non-null  float64
#  47  hospice_morgue_km                      30471 non-null  float64
#  48  university_km                          30471 non-null  float64
#  49  workplaces_km                          30471 non-null  float64
#  50  shopping_centers_km                    30471 non-null  float64
#  51  office_km                              30471 non-null  float64
#  52  additional_education_km                30471 non-null  float64
#  53  preschool_km                           30471 non-null  float64
#  54  big_church_km                          30471 non-null  float64
#  55  church_synagogue_km                    30471 non-null  float64
#  56  theater_km                             30471 non-null  float64
#  57  museum_km                              30471 non-null  float64
#  58  ecology                                30471 non-null  object
#  59  mosque_count_1000                      30471 non-null  int64
#  60  price_doc                              30471 non-null  int64
# dtypes: float64(41), int64(14), object(6)
# memory usage: 14.2+ MB

# %%
display(sber_data['sub_area'].value_counts())
# Out:
# Poselenie Sosenskoe               1776
# Nekrasovka                        1611
# Poselenie Vnukovskoe              1372
# Poselenie Moskovskij               925
# Poselenie Voskresenskoe            713
#                                   ...
# Molzhaninovskoe                      3
# Poselenie Kievskij                   2
# Poselenie Shhapovskoe                2
# Poselenie Klenovskoe                 1
# Poselenie Mihajlovo-Jarcevskoe       1
# Name: sub_area, Length: 146, dtype: int64

# %%
df = sber_data.loc[sber_data['sub_area'].str[0].isin(['M'])]

# %%
df['sub_area'].value_counts()
# Out:
# Mitino                   679
# Mar'ino                  508
# Mozhajskoe               197
# Mar'ina Roshha           116
# Matushkino               111
# Moskvorech'e-Saburovo     99
# Meshhanskoe               94
# Marfino                   85
# Metrogorodok              58
# Molzhaninovskoe            3
# Name: sub_area, dtype: int64

# %%
sber_data[sber_data['price_doc'] == sber_data['price_doc'].max()]['price_doc']
# Out:
# 2118    111111112
# Name: price_doc, dtype: int64

# %%
fig = plt.figure(figsize=(10, 7))
boxplot = sns.boxplot(
    data=sber_data,
    y='ecology',
    x='price_doc',
    orient='h',
    width=0.9)

# %%
fig = plt.figure(figsize=(16, 8))
axes = fig.add_axes([0, 0, 1, 1])
axes.scatter(
    x=sber_data['price_doc'], 
    y=sber_data['kremlin_km'], 
    s=3,
    marker='o',
    c = 'blue'
);

# %%
display(sber_data.isnull().tail(10))
# Out:
#           id  full_sq  life_sq  floor  sub_area  preschool_quota  \
# 30461  False    False    False  False     False            False
# 30462  False    False    False  False     False            False
# 30463  False    False    False  False     False            False
# 30464  False    False    False  False     False            False
# 30465  False    False     True  False     False            False
# 30466  False    False    False  False     False            False
# 30467  False    False    False  False     False            False
# 30468  False    False     True  False     False             True
# 30469  False    False    False  False     False            False
# 30470  False    False    False  False     False            False
#
#        preschool_education_centers_raion  school_quota  \
# 30461                              False         False
# 30462                              False         False
# 30463                              False         False
# 30464                              False         False
# 30465                              False         False
# 30466                              False         False
# 30467                              False         False
# 30468                              False          True
# 30469                              False         False
# 30470                              False         False
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 30461                           False                                  False
# 30462                           False                                  False
# 30463                           False                                  False
# 30464                           False                                  False
# 30465                           False                                  False
# 30466                           False                                  False
# 30467                           False                                  False
# 30468                           False                                  False
# 30469                           False                                  False
# 30470                           False                                  False
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 30461  ...      False                    False         False          False
# 30462  ...      False                    False         False          False
# 30463  ...      False                    False         False          False
# 30464  ...      False                    False         False          False
# 30465  ...      False                    False         False          False
# 30466  ...      False                    False         False          False
# 30467  ...      False                    False         False          False
# 30468  ...      False                    False         False          False
# 30469  ...      False                    False         False          False
# 30470  ...      False                    False         False          False
#
#        church_synagogue_km  theater_km  museum_km  ecology  mosque_count_1000  \
# 30461                False       False      False    False              False
# 30462                False       False      False    False              False
# 30463                False       False      False    False              False
# 30464                False       False      False    False              False
# 30465                False       False      False    False              False
# 30466                False       False      False    False              False
# 30467                False       False      False    False              False
# 30468                False       False      False    False              False
# 30469                False       False      False    False              False
# 30470                False       False      False    False              False
#
#        price_doc
# 30461      False
# 30462      False
# 30463      False
# 30464      False
# 30465      False
# 30466      False
# 30467      False
# 30468      False
# 30469      False
# 30470      False
#
# [10 rows x 61 columns]

# %%
sber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     30471 non-null  int64
#  1   full_sq                                30471 non-null  int64
#  2   life_sq                                24088 non-null  float64
#  3   floor                                  30304 non-null  float64
#  4   sub_area                               30471 non-null  object
#  5   preschool_quota                        23783 non-null  float64
#  6   preschool_education_centers_raion      30471 non-null  int64
#  7   school_quota                           23786 non-null  float64
#  8   school_education_centers_raion         30471 non-null  int64
#  9   school_education_centers_top_20_raion  30471 non-null  int64
#  10  hospital_beds_raion                    16030 non-null  float64
#  11  healthcare_centers_raion               30471 non-null  int64
#  12  university_top_20_raion                30471 non-null  int64
#  13  sport_objects_raion                    30471 non-null  int64
#  14  additional_education_raion             30471 non-null  int64
#  15  culture_objects_top_25_raion           30471 non-null  int64
#  16  shopping_centers_raion                 30471 non-null  int64
#  17  office_raion                           30471 non-null  int64
#  18  oil_chemistry_raion                    30471 non-null  object
#  19  railroad_terminal_raion                30471 non-null  object
#  20  nuclear_reactor_raion                  30471 non-null  object
#  21  metro_min_avto                         30471 non-null  float64
#  22  metro_km_avto                          30471 non-null  float64
#  23  metro_min_walk                         30446 non-null  float64
#  24  metro_km_walk                          30446 non-null  float64
#  25  kindergarten_km                        30471 non-null  float64
#  26  school_km                              30471 non-null  float64
#  27  park_km                                30471 non-null  float64
#  28  green_zone_km                          30471 non-null  float64
#  29  industrial_km                          30471 non-null  float64
#  30  railroad_station_walk_km               30446 non-null  float64
#  31  railroad_station_walk_min              30446 non-null  float64
#  32  public_transport_station_km            30471 non-null  float64
#  33  public_transport_station_min_walk      30471 non-null  float64
#  34  mkad_km                                30471 non-null  float64
#  35  ttk_km                                 30471 non-null  float64
#  36  sadovoe_km                             30471 non-null  float64
#  37  bulvar_ring_km                         30471 non-null  float64
#  38  kremlin_km                             30471 non-null  float64
#  39  big_road1_1line                        30471 non-null  object
#  40  big_market_km                          30471 non-null  float64
#  41  market_shop_km                         30471 non-null  float64
#  42  fitness_km                             30471 non-null  float64
#  43  swim_pool_km                           30471 non-null  float64
#  44  ice_rink_km                            30471 non-null  float64
#  45  stadium_km                             30471 non-null  float64
#  46  basketball_km                          30471 non-null  float64
#  47  hospice_morgue_km                      30471 non-null  float64
#  48  university_km                          30471 non-null  float64
#  49  workplaces_km                          30471 non-null  float64
#  50  shopping_centers_km                    30471 non-null  float64
#  51  office_km                              30471 non-null  float64
#  52  additional_education_km                30471 non-null  float64
#  53  preschool_km                           30471 non-null  float64
#  54  big_church_km                          30471 non-null  float64
#  55  church_synagogue_km                    30471 non-null  float64
#  56  theater_km                             30471 non-null  float64
#  57  museum_km                              30471 non-null  float64
#  58  ecology                                30471 non-null  object
#  59  mosque_count_1000                      30471 non-null  int64
#  60  price_doc                              30471 non-null  int64
# dtypes: float64(41), int64(14), object(6)
# memory usage: 14.2+ MB

# %%
cols_null_percent = sber_data.isnull().mean() * 100

# %%
cols_null_percent
# Out:
# id                    0.000000
# full_sq               0.000000
# life_sq              20.947786
# floor                 0.548062
# sub_area              0.000000
#                        ...
# theater_km            0.000000
# museum_km             0.000000
# ecology               0.000000
# mosque_count_1000     0.000000
# price_doc             0.000000
# Length: 61, dtype: float64

# %%
cols_with_null = cols_null_percent[cols_null_percent>0].sort_values(ascending=False)
display(cols_with_null)
# Out:
# hospital_beds_raion          47.392603
# preschool_quota              21.948738
# school_quota                 21.938893
# life_sq                      20.947786
# floor                         0.548062
# metro_min_walk                0.082045
# metro_km_walk                 0.082045
# railroad_station_walk_km      0.082045
# railroad_station_walk_min     0.082045
# dtype: float64

# %%
cols_with_null.plot(
    kind='bar',
    figsize=(10, 4),
    title='Распределение пропусков в данных'
);

# %%
colors = ['blue', 'yellow'] 
fig = plt.figure(figsize=(10, 4))
cols = cols_with_null.index
ax = sns.heatmap(
    sber_data[cols].isnull(),
    cmap=sns.color_palette(colors),
)

# %%
#создаем копию исходной таблицы
drop_data = sber_data.copy()
#задаем минимальный порог: вычисляем 70% от числа строк
thresh = drop_data.shape[0]*0.7
#удаляем столбцы, в которых более 30% (100-70) пропусков
drop_data = drop_data.dropna(thresh=thresh, axis=1)
#удаляем записи, в которых есть хотя бы 1 пропуск
drop_data = drop_data.dropna(how='any', axis=0)
#отображаем результирующую долю пропусков
drop_data.isnull().mean()
# Out:
# id                                       0.0
# full_sq                                  0.0
# life_sq                                  0.0
# floor                                    0.0
# sub_area                                 0.0
# preschool_quota                          0.0
# preschool_education_centers_raion        0.0
# school_quota                             0.0
# school_education_centers_raion           0.0
# school_education_centers_top_20_raion    0.0
# healthcare_centers_raion                 0.0
# university_top_20_raion                  0.0
# sport_objects_raion                      0.0
# additional_education_raion               0.0
# culture_objects_top_25_raion             0.0
# shopping_centers_raion                   0.0
# office_raion                             0.0
# oil_chemistry_raion                      0.0
# railroad_terminal_raion                  0.0
# nuclear_reactor_raion                    0.0
# metro_min_avto                           0.0
# metro_km_avto                            0.0
# metro_min_walk                           0.0
# metro_km_walk                            0.0
# kindergarten_km                          0.0
# school_km                                0.0
# park_km                                  0.0
# green_zone_km                            0.0
# industrial_km                            0.0
# railroad_station_walk_km                 0.0
# railroad_station_walk_min                0.0
# public_transport_station_km              0.0
# public_transport_station_min_walk        0.0
# mkad_km                                  0.0
# ttk_km                                   0.0
# sadovoe_km                               0.0
# bulvar_ring_km                           0.0
# kremlin_km                               0.0
# big_road1_1line                          0.0
# big_market_km                            0.0
# market_shop_km                           0.0
# fitness_km                               0.0
# swim_pool_km                             0.0
# ice_rink_km                              0.0
# stadium_km                               0.0
# basketball_km                            0.0
# hospice_morgue_km                        0.0
# university_km                            0.0
# workplaces_km                            0.0
# shopping_centers_km                      0.0
# office_km                                0.0
# additional_education_km                  0.0
# preschool_km                             0.0
# big_church_km                            0.0
# church_synagogue_km                      0.0
# theater_km                               0.0
# museum_km                                0.0
# ecology                                  0.0
# mosque_count_1000                        0.0
# price_doc                                0.0
# dtype: float64

# %%
print(drop_data.shape)
# Out:
# (20888, 60)

# %%
cols = cols_with_null.index
sber_data[cols].hist(figsize=(20, 8));

# %%
#создаем копию исходной таблицы
fill_data = sber_data.copy()

# %%
values = {
    'life_sq': fill_data['full_sq'],
    'metro_min_walk': fill_data['metro_min_walk'].median(),
    'metro_km_walk': fill_data['metro_km_walk'].median(),
    'railroad_station_walk_km': fill_data['railroad_station_walk_km'].median(),
    'railroad_station_walk_min': fill_data['railroad_station_walk_min'].median(),
    'hospital_beds_raion': fill_data['hospital_beds_raion'].mode()[0],
    'preschool_quota': fill_data['preschool_quota'].mode()[0],
    'school_quota': fill_data['school_quota'].mode()[0],
    'floor': fill_data['floor'].mode()[0]
}

# %%
fill_data = fill_data.fillna(values)
#выводим результирующую долю пропусков
fill_data.isnull().mean()
# Out:
# id                   0.0
# full_sq              0.0
# life_sq              0.0
# floor                0.0
# sub_area             0.0
#                     ...
# theater_km           0.0
# museum_km            0.0
# ecology              0.0
# mosque_count_1000    0.0
# price_doc            0.0
# Length: 61, dtype: float64

# %%
cols = cols_with_null.index
fill_data[cols].hist(figsize=(20, 8));

# %%
indicator_data = sber_data.copy()

# %%
#в цикле пробегаемся по названиям столбцов с пропусками
for col in cols_with_null.index:
    #создаем новый признак-индикатор как col_was_null
    indicator_data[col + '_was_null'] = indicator_data[col].isnull()
#создаем словарь имя столбца: число(признак) на который надо заменить пропуски   
values = {
    'life_sq': indicator_data['full_sq'],
    'metro_min_walk': indicator_data['metro_min_walk'].median(),
    'metro_km_walk': indicator_data['metro_km_walk'].median(),
    'railroad_station_walk_km': indicator_data['railroad_station_walk_km'].median(),
    'railroad_station_walk_min': indicator_data['railroad_station_walk_min'].median(),
    'hospital_beds_raion': indicator_data['hospital_beds_raion'].mode()[0],
    'preschool_quota': indicator_data['preschool_quota'].mode()[0],
    'school_quota': indicator_data['school_quota'].mode()[0],
    'floor': indicator_data['floor'].mode()[0]
}

# %%
#заполняем пропуски в соответствии с заявленным словарем
indicator_data = indicator_data.fillna(values)

# %%
indicator_data
# Out:
#           id  full_sq  life_sq  floor              sub_area  preschool_quota  \
# 0          1       43     27.0    4.0              Bibirevo           5001.0
# 1          2       34     19.0    3.0     Nagatinskij Zaton           3119.0
# 2          3       43     29.0    2.0        Tekstil'shhiki           1463.0
# 3          4       89     50.0    9.0                Mitino           6839.0
# 4          5       77     77.0    4.0             Basmannoe           3240.0
# ...      ...      ...      ...    ...                   ...              ...
# 30466  30469       44     27.0    7.0              Otradnoe           5088.0
# 30467  30470       86     59.0    3.0              Tverskoe           1874.0
# 30468  30471       45     45.0   10.0  Poselenie Vnukovskoe           2395.0
# 30469  30472       64     32.0    5.0          Obruchevskoe           2372.0
# 30470  30473       43     28.0    1.0           Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# 0                                      5       11065.0
# 1                                      5        6237.0
# 2                                      4        5580.0
# 3                                      9       17063.0
# 4                                      7        7770.0
# ...                                  ...           ...
# 30466                                  4       12721.0
# 30467                                  4        6772.0
# 30468                                  0        7377.0
# 30469                                  6        6083.0
# 30470                                  4        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 0                                   5                                      0
# 1                                   8                                      0
# 2                                   7                                      0
# 3                                  10                                      0
# 4                                   9                                      0
# ...                               ...                                    ...
# 30466                               4                                      0
# 30467                               4                                      1
# 30468                               0                                      0
# 30469                               8                                      0
# 30470                               4                                      0
#
#        ...  price_doc  hospital_beds_raion_was_null  preschool_quota_was_null  \
# 0      ...    5850000                         False                     False
# 1      ...    6000000                         False                     False
# 2      ...    5700000                         False                     False
# 3      ...   13100000                          True                     False
# 4      ...   16331452                         False                     False
# ...    ...        ...                           ...                       ...
# 30466  ...    7400000                          True                     False
# 30467  ...   25000000                         False                     False
# 30468  ...    6970959                          True                      True
# 30469  ...   13500000                         False                     False
# 30470  ...    5600000                         False                     False
#
#        school_quota_was_null  life_sq_was_null  floor_was_null  \
# 0                      False             False           False
# 1                      False             False           False
# 2                      False             False           False
# 3                      False             False           False
# 4                      False             False           False
# ...                      ...               ...             ...
# 30466                  False             False           False
# 30467                  False             False           False
# 30468                   True              True           False
# 30469                  False             False           False
# 30470                  False             False           False
#
#        metro_min_walk_was_null  metro_km_walk_was_null  \
# 0                        False                   False
# 1                        False                   False
# 2                        False                   False
# 3                        False                   False
# 4                        False                   False
# ...                        ...                     ...
# 30466                    False                   False
# 30467                    False                   False
# 30468                    False                   False
# 30469                    False                   False
# 30470                    False                   False
#
#       railroad_station_walk_km_was_null railroad_station_walk_min_was_null
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
# 3                                 False                              False
# 4                                 False                              False
# ...                                 ...                                ...
# 30466                             False                              False
# 30467                             False                              False
# 30468                             False                              False
# 30469                             False                              False
# 30470                             False                              False
#
# [30471 rows x 70 columns]

# %%
#выводим результирующую долю пропусков
indicator_data.isnull().mean()
# Out:
# id                                    0.0
# full_sq                               0.0
# life_sq                               0.0
# floor                                 0.0
# sub_area                              0.0
#                                      ...
# floor_was_null                        0.0
# metro_min_walk_was_null               0.0
# metro_km_walk_was_null                0.0
# railroad_station_walk_km_was_null     0.0
# railroad_station_walk_min_was_null    0.0
# Length: 70, dtype: float64

# %%
indicator_data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# 2                               7                                      0  ...
# 3                              10                                      0  ...
# 4                               9                                      0  ...
#
#    price_doc  hospital_beds_raion_was_null  preschool_quota_was_null  \
# 0    5850000                         False                     False
# 1    6000000                         False                     False
# 2    5700000                         False                     False
# 3   13100000                          True                     False
# 4   16331452                         False                     False
#
#    school_quota_was_null  life_sq_was_null  floor_was_null  \
# 0                  False             False           False
# 1                  False             False           False
# 2                  False             False           False
# 3                  False             False           False
# 4                  False             False           False
#
#    metro_min_walk_was_null  metro_km_walk_was_null  \
# 0                    False                   False
# 1                    False                   False
# 2                    False                   False
# 3                    False                   False
# 4                    False                   False
#
#   railroad_station_walk_km_was_null railroad_station_walk_min_was_null
# 0                             False                              False
# 1                             False                              False
# 2                             False                              False
# 3                             False                              False
# 4                             False                              False
#
# [5 rows x 70 columns]

# %%
#создаём копию исходной таблицы
combine_data = sber_data.copy()

#отбрасываем столбцы с числом пропусков более 30% (100-70)
n = combine_data.shape[0] #число строк в таблице
thresh = n*0.7
combine_data = combine_data.dropna(thresh=thresh, axis=1)

#отбрасываем строки с числом пропусков более 2 в строке
m = combine_data.shape[1] #число признаков после удаления столбцов
combine_data = combine_data.dropna(thresh=m-2, axis=0)

#создаём словарь 'имя_столбца': число (признак), на который надо заменить пропуски 
values = {
    'life_sq': combine_data['full_sq'],
    'metro_min_walk': combine_data['metro_min_walk'].median(),
    'metro_km_walk': combine_data['metro_km_walk'].median(),
    'railroad_station_walk_km': combine_data['railroad_station_walk_km'].median(),
    'railroad_station_walk_min': combine_data['railroad_station_walk_min'].median(),
    'preschool_quota': combine_data['preschool_quota'].mode()[0],
    'school_quota': combine_data['school_quota'].mode()[0],
    'floor': combine_data['floor'].mode()[0]
}
#заполняем оставшиеся записи константами в соответствии со словарем values
combine_data = combine_data.fillna(values)
#выводим результирующую долю пропусков
display(combine_data.isnull().mean())
# Out:
# id                                       0.0
# full_sq                                  0.0
# life_sq                                  0.0
# floor                                    0.0
# sub_area                                 0.0
# preschool_quota                          0.0
# preschool_education_centers_raion        0.0
# school_quota                             0.0
# school_education_centers_raion           0.0
# school_education_centers_top_20_raion    0.0
# healthcare_centers_raion                 0.0
# university_top_20_raion                  0.0
# sport_objects_raion                      0.0
# additional_education_raion               0.0
# culture_objects_top_25_raion             0.0
# shopping_centers_raion                   0.0
# office_raion                             0.0
# oil_chemistry_raion                      0.0
# railroad_terminal_raion                  0.0
# nuclear_reactor_raion                    0.0
# metro_min_avto                           0.0
# metro_km_avto                            0.0
# metro_min_walk                           0.0
# metro_km_walk                            0.0
# kindergarten_km                          0.0
# school_km                                0.0
# park_km                                  0.0
# green_zone_km                            0.0
# industrial_km                            0.0
# railroad_station_walk_km                 0.0
# railroad_station_walk_min                0.0
# public_transport_station_km              0.0
# public_transport_station_min_walk        0.0
# mkad_km                                  0.0
# ttk_km                                   0.0
# sadovoe_km                               0.0
# bulvar_ring_km                           0.0
# kremlin_km                               0.0
# big_road1_1line                          0.0
# big_market_km                            0.0
# market_shop_km                           0.0
# fitness_km                               0.0
# swim_pool_km                             0.0
# ice_rink_km                              0.0
# stadium_km                               0.0
# basketball_km                            0.0
# hospice_morgue_km                        0.0
# university_km                            0.0
# workplaces_km                            0.0
# shopping_centers_km                      0.0
# office_km                                0.0
# additional_education_km                  0.0
# preschool_km                             0.0
# big_church_km                            0.0
# church_synagogue_km                      0.0
# theater_km                               0.0
# museum_km                                0.0
# ecology                                  0.0
# mosque_count_1000                        0.0
# price_doc                                0.0
# dtype: float64

# %%
print(combine_data.shape)
# Out:
# (26800, 60)

# %%
sber_data.isnull().count()
# Out:
# id                   30471
# full_sq              30471
# life_sq              30471
# floor                30471
# sub_area             30471
#                      ...
# theater_km           30471
# museum_km            30471
# ecology              30471
# mosque_count_1000    30471
# price_doc            30471
# Length: 61, dtype: int64

# %%
sber_data.isnull().median()
# Out:
# id                   0.0
# full_sq              0.0
# life_sq              0.0
# floor                0.0
# sub_area             0.0
#                     ...
# theater_km           0.0
# museum_km            0.0
# ecology              0.0
# mosque_count_1000    0.0
# price_doc            0.0
# Length: 61, dtype: float64

# %%
sber_data.isnull().mean()
# Out:
# id                   0.000000
# full_sq              0.000000
# life_sq              0.209478
# floor                0.005481
# sub_area             0.000000
#                        ...
# theater_km           0.000000
# museum_km            0.000000
# ecology              0.000000
# mosque_count_1000    0.000000
# price_doc            0.000000
# Length: 61, dtype: float64

# %%
sber_data.isnull().sum()
# Out:
# id                      0
# full_sq                 0
# life_sq              6383
# floor                 167
# sub_area                0
#                      ...
# theater_km              0
# museum_km               0
# ecology                 0
# mosque_count_1000       0
# price_doc               0
# Length: 61, dtype: int64

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('test_data.csv')


n = df.shape[0] 
thresh = n*0.5
df = df.dropna(thresh=thresh, axis=1)

#отбрасываем строки с числом пропусков более 2 в строке
m = df.shape[1] #число признаков после удаления столбцов
df = df.dropna(thresh=m-2, axis=0)

#создаём словарь 'имя_столбца': число (признак), на который надо заменить пропуски 
values = {
    'one': df['one'].mean(),
    'two': df['two'].mean(),
    'three': df['three'].mean(),
    'four': df['four'].mode()[0]
}
#заполняем оставшиеся записи константами в соответствии со словарем values
df = df.fillna(values)
#выводим результирующую долю пропусков
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-74-8835c6a3625b> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.read_csv('test_data.csv')
#       4
#       5
#
# c:\Users\mania\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# c:\Users\mania\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# c:\Users\mania\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# c:\Users\mania\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# c:\Users\mania\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# c:\Users\mania\anaconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# c:\Users\mania\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_data.csv'

# %%
sber_data['life_sq'].describe()
# Out:
# count    24088.000000
# mean        34.403271
# std         52.285733
# min          0.000000
# 25%         20.000000
# 50%         30.000000
# 75%         43.000000
# max       7478.000000
# Name: life_sq, dtype: float64

# %%
sber_data.describe()
# Out:
#                  id       full_sq       life_sq         floor  \
# count  30471.000000  30471.000000  24088.000000  30304.000000
# mean   15237.917397     54.214269     34.403271      7.670803
# std     8796.501536     38.031487     52.285733      5.319989
# min        1.000000      0.000000      0.000000      0.000000
# 25%     7620.500000     38.000000     20.000000      3.000000
# 50%    15238.000000     49.000000     30.000000      6.500000
# 75%    22855.500000     63.000000     43.000000     11.000000
# max    30473.000000   5326.000000   7478.000000     77.000000
#
#        preschool_quota  preschool_education_centers_raion  school_quota  \
# count     23783.000000                       30471.000000  23786.000000
# mean       3271.272464                           4.065111   8324.970739
# std        2169.759592                           2.993795   4289.734174
# min           0.000000                           0.000000   1012.000000
# 25%        1874.000000                           2.000000   5782.000000
# 50%        2854.000000                           4.000000   7377.000000
# 75%        4050.000000                           6.000000   9891.000000
# max       11926.000000                          13.000000  24750.000000
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# count                    30471.000000                           30471.000000
# mean                         4.705031                               0.109678
# std                          3.445105                               0.333328
# min                          0.000000                               0.000000
# 25%                          2.000000                               0.000000
# 50%                          5.000000                               0.000000
# 75%                          7.000000                               0.000000
# max                         14.000000                               2.000000
#
#        hospital_beds_raion  ...  shopping_centers_km     office_km  \
# count         16030.000000  ...         30471.000000  30471.000000
# mean           1190.738677  ...             1.505808      2.010973
# std            1057.015001  ...             2.253759      2.306446
# min               0.000000  ...             0.000000      0.000000
# 25%             520.000000  ...             0.483758      0.555231
# 50%             990.000000  ...             0.839647      1.052999
# 75%            1786.000000  ...             1.549517      3.046687
# max            4849.000000  ...            26.259543     18.958933
#
#        additional_education_km  preschool_km  big_church_km  \
# count             30471.000000  30471.000000   30471.000000
# mean                  1.328488      1.345235       2.330047
# std                   1.526219      3.053600       2.986937
# min                   0.000000      0.000000       0.004072
# 25%                   0.474842      0.285124       0.860469
# 50%                   0.899034      0.493048       1.490794
# 75%                   1.571062      0.936324       2.922264
# max                  24.268209     47.394706      45.669060
#
#        church_synagogue_km    theater_km     museum_km  mosque_count_1000  \
# count         30471.000000  30471.000000  30471.000000       30471.000000
# mean              0.972014      9.638074      7.063236           0.019166
# std               0.748876      7.112284      5.702807           0.137110
# min               0.000000      0.026788      0.007903           0.000000
# 25%               0.532480      4.225254      2.879357           0.000000
# 50%               0.860037      8.612007      5.643495           0.000000
# 75%               1.248480     13.459593     10.328587           0.000000
# max              15.615728     87.600690     59.203148           1.000000
#
#           price_doc
# count  3.047100e+04
# mean   7.123035e+06
# std    4.780111e+06
# min    1.000000e+05
# 25%    4.740002e+06
# 50%    6.274411e+06
# 75%    8.300000e+06
# max    1.111111e+08
#
# [8 rows x 55 columns]

# %%
print(sber_data[sber_data['life_sq'] == 0].shape[0])
# Out:
# 45

# %%
sber_data[sber_data['life_sq'] == 0]
# Out:
#           id  full_sq  life_sq  floor                 sub_area  \
# 858      859       78      0.0    2.0               Nekrasovka
# 1596    1599       59      0.0    5.0               Nekrasovka
# 2778    2781       38      0.0   17.0               Nekrasovka
# 3426    3429       71      0.0    3.0               Nekrasovka
# 3800    3803       57      0.0   10.0     Poselenie Moskovskij
# 4138    4141       61      0.0    4.0                 Tverskoe
# 4311    4314       44      0.0    9.0      Poselenie Sosenskoe
# 5879    5882       61      0.0    6.0               Nekrasovka
# 10275  10278       37      0.0    6.0               Nekrasovka
# 11653  11656       54      0.0   12.0                   Mitino
# 12704  12707      119      0.0    9.0                   Mitino
# 13217  13220       61      0.0   16.0               Nekrasovka
# 15363  15366       58      0.0    0.0     Poselenie Vnukovskoe
# 17660  17663       37      0.0   17.0                Izmajlovo
# 17930  17933       37      0.0    5.0  Poselenie Voskresenskoe
# 17932  17935        0      0.0    0.0  Poselenie Voskresenskoe
# 18764  18767       72      0.0   10.0     Poselenie Moskovskij
# 18901  18904       42      0.0    8.0      Poselenie Sosenskoe
# 19504  19507       52      0.0   11.0     Poselenie Vnukovskoe
# 19743  19746      102      0.0   17.0      Poselenie Sosenskoe
# 10275                 0   3824904
# 11653                 0   8620336
# 12704                 0  15254044
# 13217                 0   5944257
# 15363                 0   6867981
# 17660                 0   3712661
# 17930                 0   4651200
# 17932                 0   4425000
# 18764                 0   7731241
# 18901                 0   4088370
# 19504                 0   6185375
# 19743                 0  11900475
# 19819                 0   7325634
# 20741                 0   4725120
# 21246                 0   7775630
# 21332                 0   6640370
# 21445                 0   3166838
# 21453                 0   3411777
# 21638                 0   9377280
# 21677                 0   5591751
# 21708                 0   4278104
# 21809                 0   3116696
# 22158                 0   7047839
# 22552                 0   4684993
# 23032                 0  11523511
# 23254                 0   5615703
# 23713                 0   3572565
# 24901                 0   5849049
# 25107                 0   4771580
# 25291                 0   6626044
# 25366                 0   6708000
# 25459                 0   3813204
# 26894                 0   4260540
# 27651                 0   8758453
# 28377                 0   6486642
# 28817                 0   4799800
# 30273                 0   1085877
#
# [45 rows x 61 columns]

# %%
print(sber_data[sber_data['life_sq'] == 0].count())
# Out:
# id                   45
# full_sq              45
# life_sq              45
# floor                45
# sub_area             45
#                      ..
# theater_km           45
# museum_km            45
# ecology              45
# mosque_count_1000    45
# price_doc            45
# Length: 61, dtype: int64

# %%
display(sber_data[sber_data['life_sq'] > 7000])
# Out:
#           id  full_sq  life_sq  floor                 sub_area  \
# 13546  13549       79   7478.0    8.0  Poselenie Voskresenskoe
#
#        preschool_quota  preschool_education_centers_raion  school_quota  \
# 13546              NaN                                  0           NaN
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 13546                               0                                      0
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 13546  ...   5.072389                 1.210613      0.826052       1.582378
#
#        church_synagogue_km  theater_km  museum_km  ecology mosque_count_1000  \
# 13546             0.756119   21.472421  14.917332  no data                 0
#
#       price_doc
# 13546   7705000
#
# [1 rows x 61 columns]

# %%
outliers = sber_data[sber_data['life_sq'] > sber_data['full_sq']]
print(outliers.shape[0])
# Out:
# 37

# %%
outliers
# Out:
#           id  full_sq  life_sq  floor                   sub_area  \
# 1084    1085       44    281.0    6.0                   Bibirevo
# 1188    1189        9     44.0    3.0                  Veshnjaki
# 1822    1825       18     38.0    NaN                   Ljublino
# 1863    1866       30    178.0    4.0                Presnenskoe
# 2009    2012        5     40.0    5.0                 Gol'janovo
# 4385    4388       73    426.0   17.0                 Vojkovskoe
# 6336    6339       37    191.0    5.0           Kosino-Uhtomskoe
# 6531    6534       80     88.0    9.0      Pokrovskoe Streshnevo
# 6993    6996       73     77.0   10.0                 Nekrasovka
# 7208    7211       31    195.0    5.0                Cheremushki
# 8101    8104       37     38.0    8.0                 Nekrasovka
# 9237    9240       47    301.0    4.0         Birjulevo Zapadnoe
# 9256    9259       77    458.0   12.0                   Jasenevo
# 9482    9485       52     53.0   12.0         Juzhnoe Medvedkovo
# 9646    9649       82    802.0    5.0         Chertanovo Juzhnoe
# 11332  11335        1     40.0   10.0       Poselenie Shherbinka
# 11711  11714       56     58.0   15.0                   Kon'kovo
# 11784  11787       46     59.0   12.0             Fili Davydkovo
# 12569  12572       56     60.0    3.0                     Mitino
# 8101              0.912168    9.836242   7.288785          good
# 9237              0.474313   10.482531   3.505929  satisfactory
# 9256              0.377193   11.546313   9.512919          good
# 9482              1.367308    7.516425   6.078129          good
# 9646              1.068539    8.219991   5.556948          poor
# 11332             0.111842   23.142718  14.148537       no data
# 11711             0.863020    5.298304   6.842329          good
# 11784             1.053075    4.311112   4.427224  satisfactory
# 12569             0.854763   15.913111  15.508916          good
# 13546             0.756119   21.472421  14.917332       no data
# 13629             0.743592   11.362528  11.345507       no data
# 13797             0.685764   22.851418  13.358769       no data
# 14799             0.912168    9.836242   7.288785          good
# 16067             1.807236   18.968711  16.976119       no data
# 16116             0.920709   13.725626  12.858320       no data
# 16284             3.144256   32.292799  27.797029       no data
# 20672             0.738342   19.012614   9.823983  satisfactory
# 21080             0.455265   10.667685   6.974990          good
# 22412             0.831224    2.785129   1.506191          poor
# 22611             1.476887    8.937829   2.415292     excellent
# 22804             1.476887    8.937829   2.415292     excellent
# 24296             1.323448   13.938381  10.225384       no data
# 24428             0.912168    9.836242   7.288785          good
# 26264             1.571747    8.534274   7.604545          good
# 26342             0.550989   15.907540  15.005953          good
# 26363             1.068539    8.219991   5.556948          poor
# 29302             0.368197    3.675552   2.180548          poor
#
#       mosque_count_1000 price_doc
# 1084                  0   6200000
# 1188                  0   6300000
# 1822                  0   5200000
# 1863                  0   5900000
# 2009                  0   5770000
# 4385                  0  11918400
# 6336                  0   5400000
# 6531                  0  13801229
# 6993                  0   6290256
# 7208                  0   6400000
# 8101                  0   3622465
# 9237                  0   5600000
# 9256                  0  13750000
# 9482                  0   3000000
# 9646                  0  12031350
# 11332                 0   3357774
# 11711                 0   2000000
# 11784                 0  15000000
# 12569                 0   9897007
# 13546                 0   7705000
# 13629                 0   4900000
# 13797                 0   3550000
# 14799                 0   7488400
# 16067                 0   3661580
# 16116                 0   8762000
# 16284                 0   3759912
# 20672                 0   3707340
# 21080                 0   7200000
# 22412                 0  14923206
# 22611                 0   6555970
# 22804                 0   8586239
# 24296                 0   8167508
# 24428                 0   7419500
# 26264                 0   5983900
# 26342                 0  12900000
# 26363                 0  14430018
# 29302                 0  11000000
#
# [37 rows x 61 columns]

# %%
cleaned = sber_data.drop(outliers.index, axis=0)
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Результирующее число записей: 30434

# %%
display(sber_data['floor'].describe())
# Out:
# count    30304.000000
# mean         7.670803
# std          5.319989
# min          0.000000
# 25%          3.000000
# 50%          6.500000
# 75%         11.000000
# max         77.000000
# Name: floor, dtype: float64

# %%
display(sber_data[sber_data['floor']> 50])
# Out:
#           id  full_sq  life_sq  floor       sub_area  preschool_quota  \
# 23584  23587       57     33.0   77.0  Lomonosovskoe           3091.0
#
#        preschool_education_centers_raion  school_quota  \
# 23584                                  5        8359.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 23584                               7                                      1
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 23584  ...   0.310557                 0.731683      0.489763        0.86354
#
#        church_synagogue_km  theater_km  museum_km       ecology  \
# 23584             0.863266    2.920671   2.757058  satisfactory
#
#       mosque_count_1000 price_doc
# 23584                 0  13700000
#
# [1 rows x 61 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=sber_data, x='full_sq', ax=axes[0]);
histplot.set_title('Full Square Distribution');
boxplot = sns.boxplot(data=sber_data, x='full_sq', ax=axes[1]);
boxplot.set_title('Full Square Boxplot');

# %%
def outliers_iqr(data, feature):
    x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    outliers = data[(x<lower_bound) | (x > upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# %%
outliers, cleaned = outliers_iqr(sber_data, 'full_sq')
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 963
# Результирующее число записей: 29508

# %%
outliers
# Out:
#           id  full_sq  life_sq  floor            sub_area  preschool_quota  \
# 79        80      133     64.0    2.0           Izmajlovo           1313.0
# 128      129      325    325.0    7.0          Ivanovskoe           2697.0
# 146      147      102     64.0   11.0     Sokolinaja Gora            643.0
# 147      148      117    108.0   20.0  Nagatino-Sadovniki           2508.0
# 170      171      115     60.0    7.0          Krylatskoe           3092.0
# ...      ...      ...      ...    ...                 ...              ...
# 30320  30323      151      NaN    5.0            Jasenevo           4172.0
# 30355  30358      133      NaN   12.0           Izmajlovo           1313.0
# 30369  30372      124      NaN   12.0           Izmajlovo           1313.0
# 30397  30400      109     60.0   11.0             Ramenki            903.0
# 30441  30444      113      1.0   26.0            Tverskoe           1874.0
#
#        preschool_education_centers_raion  school_quota  \
# 79                                     4        4339.0
# 128                                    7        9439.0
# 146                                    4        5180.0
# 147                                    4        5254.0
# 170                                    7        7478.0
# ...                                  ...           ...
# 30320                                  7       10559.0
# 30355                                  4        4339.0
# 30369                                  4        4339.0
# 30397                                  8        7788.0
# 30441                                  4        6772.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 79                                  6                                      0
# 128                                 8                                      1
# 146                                 4                                      0
# 147                                 6                                      0
# 170                                 7                                      0
# ...                               ...                                    ...
# 30320                               7                                      0
# 30355                               6                                      0
# 30369                               6                                      0
# 30397                               8                                      0
# 30441                               4                                      1
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 79     ...   0.804087                 0.435858      0.676590       2.098633
# 128    ...   3.310054                 0.602138      0.369984       1.104165
# 146    ...   0.999584                 1.426903      1.163062       1.627478
# 147    ...   0.237372                 0.437805      0.157045       1.855743
# 170    ...   0.727716                 0.681249      0.165629       0.287008
# ...    ...        ...                      ...           ...            ...
# 30320  ...   2.130257                 0.683810      0.694617       1.270087
# 30355  ...   1.325438                 0.442404      0.862449       0.569742
# 30369  ...   1.325438                 0.442404      0.862449       0.569742
# 30397  ...   0.608047                 0.822709      0.435947       1.729040
# 30441  ...   0.182194                 0.000000      0.269716       0.181897
#
#        church_synagogue_km  theater_km  museum_km       ecology  \
# 79                0.968482    7.141546   5.413698          good
# 128               1.247850    2.194396   1.143931          poor
# 146               0.601487    3.449316   1.557170     excellent
# 147               1.549737    4.452140   2.014427     excellent
# 170               1.147352   12.239214   7.247341          good
# ...                    ...         ...        ...           ...
# 30320             0.808215    9.897054   8.813169          good
# 30355             0.569372    5.379698   4.738857          good
# 30369             0.569372    5.379698   4.738857          good
# 30397             0.480137    2.858389   3.224508  satisfactory
# 30441             0.184681    2.370385   0.695251     excellent
#
#       mosque_count_1000 price_doc
# 79                    0  17600000
# 128                   0   5000000
# 146                   0   4600000
# 147                   0  14103600
# 170                   0  37000000
# ...                 ...       ...
# 30320                 0  28038712
# 30355                 0  26055288
# 30369                 0  26055288
# 30397                 0  38400000
# 30441                 0  25039300
#
# [963 rows x 61 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=cleaned, x='full_sq', ax=axes[0]);
histplot.set_title('Cleaned Full Square Distribution');
boxplot = sns.boxplot(data=cleaned, x='full_sq', ax=axes[1]);
boxplot.set_title('Cleaned Full Square Boxplot');

# %%
def outliers_iqr_mod(data, feature, left=1.5, right=1.5):
    x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * left)
    upper_bound = quartile_3 + (iqr * right)
    outliers = data[(x<lower_bound) | (x> upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# %%
outliers_iqr_mod(sber_data, 'full_sq')
# Out:
# (          id  full_sq  life_sq  floor            sub_area  preschool_quota  \
#  79        80      133     64.0    2.0           Izmajlovo           1313.0
#  128      129      325    325.0    7.0          Ivanovskoe           2697.0
#  146      147      102     64.0   11.0     Sokolinaja Gora            643.0
#  147      148      117    108.0   20.0  Nagatino-Sadovniki           2508.0
#  170      171      115     60.0    7.0          Krylatskoe           3092.0
#  ...      ...      ...      ...    ...                 ...              ...
#  30320  30323      151      NaN    5.0            Jasenevo           4172.0
#  30355  30358      133      NaN   12.0           Izmajlovo           1313.0
#  30369  30372      124      NaN   12.0           Izmajlovo           1313.0
#  30397  30400      109     60.0   11.0             Ramenki            903.0
#  30441  30444      113      1.0   26.0            Tverskoe           1874.0
#
#         preschool_education_centers_raion  school_quota  \
#  79                                     4        4339.0
#  128                                    7        9439.0
#  146                                    4        5180.0
#  147                                    4        5254.0
#  170                                    7        7478.0
#  ...                                  ...           ...
#  30320                                  7       10559.0
#  30355                                  4        4339.0
#  30369                                  4        4339.0
#  30397                                  8        7788.0
#  30441                                  4        6772.0
#
#         school_education_centers_raion  school_education_centers_top_20_raion  \
#  79                                  6                                      0
#  128                                 8                                      1
#  146                                 4                                      0
#  147                                 6                                      0
#  170                                 7                                      0
#  ...                               ...                                    ...
#  30320                               7                                      0
#  30355                               6                                      0
#  30369                               6                                      0
#  30397                               8                                      0
#  30441                               4                                      1
#
#         ...  office_km  additional_education_km  preschool_km  big_church_km  \
#  79     ...   0.804087                 0.435858      0.676590       2.098633
#  128    ...   3.310054                 0.602138      0.369984       1.104165
#  146    ...   0.999584                 1.426903      1.163062       1.627478
#  147    ...   0.237372                 0.437805      0.157045       1.855743
#  170    ...   0.727716                 0.681249      0.165629       0.287008
#  ...    ...        ...                      ...           ...            ...
#  30320  ...   2.130257                 0.683810      0.694617       1.270087
#  30355  ...   1.325438                 0.442404      0.862449       0.569742
#  30369  ...   1.325438                 0.442404      0.862449       0.569742
#  30397  ...   0.608047                 0.822709      0.435947       1.729040
#  30441  ...   0.182194                 0.000000      0.269716       0.181897
#
#         church_synagogue_km  theater_km  museum_km       ecology  \
#  79                0.968482    7.141546   5.413698          good
#  128               1.247850    2.194396   1.143931          poor
#  146               0.601487    3.449316   1.557170     excellent
#  147               1.549737    4.452140   2.014427     excellent
#  170               1.147352   12.239214   7.247341          good
#  ...                    ...         ...        ...           ...
#  30320             0.808215    9.897054   8.813169          good
#  30355             0.569372    5.379698   4.738857          good
#  30369             0.569372    5.379698   4.738857          good
#  30397             0.480137    2.858389   3.224508  satisfactory
#  30441             0.184681    2.370385   0.695251     excellent
#
#        mosque_count_1000 price_doc
#  79                    0  17600000
#  128                   0   5000000
#  146                   0   4600000
#  147                   0  14103600
#  170                   0  37000000
#  ...                 ...       ...
#  30320                 0  28038712
#  30355                 0  26055288
#  30369                 0  26055288
#  30397                 0  38400000
#  30441                 0  25039300
#
#  [963 rows x 61 columns],
#            id  full_sq  life_sq  floor              sub_area  preschool_quota  \
#  0          1       43     27.0    4.0              Bibirevo           5001.0
#  1          2       34     19.0    3.0     Nagatinskij Zaton           3119.0
#  2          3       43     29.0    2.0        Tekstil'shhiki           1463.0
#  3          4       89     50.0    9.0                Mitino           6839.0
#  4          5       77     77.0    4.0             Basmannoe           3240.0
#  ...      ...      ...      ...    ...                   ...              ...
#  30466  30469       44     27.0    7.0              Otradnoe           5088.0
#  30467  30470       86     59.0    3.0              Tverskoe           1874.0
#  30468  30471       45      NaN   10.0  Poselenie Vnukovskoe              NaN
#  30469  30472       64     32.0    5.0          Obruchevskoe           2372.0
#  30470  30473       43     28.0    1.0           Novogireevo           2215.0
#
#         preschool_education_centers_raion  school_quota  \
#  0                                      5       11065.0
#  1                                      5        6237.0
#  2                                      4        5580.0
#  3                                      9       17063.0
#  4                                      7        7770.0
#  ...                                  ...           ...
#  30466                                  4       12721.0
#  30467                                  4        6772.0
#  30468                                  0           NaN
#  30469                                  6        6083.0
#  30470                                  4        5824.0
#
#         school_education_centers_raion  school_education_centers_top_20_raion  \
#  0                                   5                                      0
#  1                                   8                                      0
#  2                                   7                                      0
#  3                                  10                                      0
#  4                                   9                                      0
#  ...                               ...                                    ...
#  30466                               4                                      0
#  30467                               4                                      1
#  30468                               0                                      0
#  30469                               8                                      0
#  30470                               4                                      0
#
#         ...  office_km  additional_education_km  preschool_km  big_church_km  \
#  0      ...   0.637189                 0.947962      0.177975       0.625783
#  1      ...   0.688796                 1.072315      0.273345       0.967821
#  2      ...   1.543049                 0.391957      0.158072       3.178751
#  3      ...   0.934273                 0.892674      0.236455       1.031777
#  4      ...   0.077901                 0.810801      0.376838       0.378756
#  ...    ...        ...                      ...           ...            ...
#  30466  ...   1.103579                 0.167718      0.349899       1.235066
#  30467  ...   0.069986                 0.086552      0.362681       0.850385
#  30468  ...   4.338453                 1.339078      1.234235       1.192543
#  30469  ...   1.204798                 1.340017      0.130667       1.644053
#  30470  ...   2.108265                 0.825811      0.378950       0.480531
#
#         church_synagogue_km  theater_km  museum_km       ecology  \
#  0                 0.628187   14.053047   7.389498          good
#  1                 0.471447    6.829889   0.709260     excellent
#  2                 0.755946    4.273200   3.156423          poor
#  3                 1.561505   16.990677  16.041521          good
#  4                 0.121681    1.112486   1.800125     excellent
#  ...                    ...         ...        ...           ...
#  30466             0.612359    7.482165   4.836787          good
#  30467             0.310021    0.778428   1.450108          poor
#  30468             1.186621   13.459593   9.890758       no data
#  30469             0.476021    2.088193   4.119706  satisfactory
#  30470             0.867332    0.688707   0.127867          poor
#
#        mosque_count_1000 price_doc
#  0                     0   5850000
#  1                     0   6000000
#  2                     0   5700000
#  3                     0  13100000
#  4                     0  16331452
#  ...                 ...       ...
#  30466                 0   7400000
#  30467                 0  25000000
#  30468                 0   6970959
#  30469                 0  13500000
#  30470                 0   5600000
#
#  [29508 rows x 61 columns])

# %%
outliers, cleaned = outliers_iqr_mod(sber_data, 'full_sq')
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 963
# Результирующее число записей: 29508

# %%
outliers, cleaned = outliers_iqr_mod(sber_data, 'full_sq',1,6)
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 59
# Результирующее число записей: 30403

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=cleaned, x='full_sq', ax=axes[0]);
histplot.set_title('Cleaned Full Square Distribution');
boxplot = sns.boxplot(data=cleaned, x='full_sq', ax=axes[1]);
boxplot.set_title('Cleaned Full Square Boxplot');

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#гистограмма исходного признака
histplot = sns.histplot(sber_data['mkad_km'], bins=30, ax=axes[0])
histplot.set_title('MKAD Km Distribution');

#гистограмма в логарифмическом масштабе
log_mkad_km= np.log(sber_data['mkad_km'] + 1)
histplot = sns.histplot(log_mkad_km , bins=30, ax=axes[1])
histplot.set_title('Log MKAD Km Distribution');

# %%
print(log_mkad_km.skew())
# -0.14263612203024953
# Out:
# -0.14263612203024953

# %%
def outliers_z_score(data, feature, log_scale=False):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - 3 * sigma
    upper_bound = mu + 3 * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# %%
outliers, cleaned = outliers_z_score(sber_data, 'mkad_km', log_scale=True)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 33
# Результирующее число записей: 30438

# %%
print(outliers['sub_area'].unique())
# Out:
# ['Poselenie Rogovskoe' 'Poselenie Kievskij']

# %%
outliers, cleaned = outliers_z_score(sber_data, 'mkad_km')
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 253
# Результирующее число записей: 30218

# %%
print(outliers['sub_area'].unique())
# Out:
# ['Poselenie Pervomajskoe' 'Poselenie Marushkinskoe'
#  'Poselenie Krasnopahorskoe' 'Poselenie Novofedorovskoe'
#  'Poselenie Voronovskoe' 'Poselenie Klenovskoe' 'Poselenie Rogovskoe'
#  'Poselenie Kievskij' 'Poselenie Mihajlovo-Jarcevskoe']

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_mkad_km = np.log(sber_data['mkad_km'] + 1)
histplot = sns.histplot(log_mkad_km, bins=30, ax=ax)
histplot.axvline(log_mkad_km.mean(), color='k', lw=2)
histplot.axvline(log_mkad_km.mean()+ 3 * log_mkad_km.std(), color='k', ls='--', lw=2)
histplot.axvline(log_mkad_km.mean()- 3 * log_mkad_km.std(), color='k', ls='--', lw=2)
histplot.set_title('Log MKAD Km Distribution');

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
mkad_km = sber_data['mkad_km']
histplot = sns.histplot(mkad_km, bins=30, ax=ax)
histplot.axvline(mkad_km.mean(), color='k', lw=2)
histplot.axvline(mkad_km.mean()+ 3 * mkad_km.std(), color='k', ls='--', lw=2)
histplot.axvline(mkad_km.mean()- 3 * mkad_km.std(), color='k', ls='--', lw=2)
histplot.set_title('MKAD Km Distribution');

# %%
def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# %%
outliers, cleaned = outliers_z_score_mod(sber_data, 'mkad_km',4,4)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 33
# Результирующее число записей: 30438

# %%
outliers, cleaned = outliers_z_score_mod(sber_data, 'mkad_km',True,3,3.5)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 0
# Результирующее число записей: 30471

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_mkad_km = np.log(sber_data['price_doc'] + 1)
histplot = sns.histplot(log_mkad_km, bins=30, ax=ax)
histplot.axvline(log_mkad_km.mean(), color='k', lw=2)
histplot.axvline(log_mkad_km.mean()+ 3 * log_mkad_km.std(), color='k', ls='--', lw=2)
histplot.axvline(log_mkad_km.mean()- 3 * log_mkad_km.std(), color='k', ls='--', lw=2)
histplot.set_title('Log MKAD Km Distribution');

# %%
def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# %%
outliers, cleaned = outliers_z_score_mod(sber_data, 'price_doc',True,3.7,3.7)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 52
# Результирующее число записей: 30419

# %%
def outliers_iqr_mod_log(data, feature, log_scale=False, left=1.5, right=1.5):
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * left)
    upper_bound = quartile_3 + (iqr * right)
    outliers = data[(x<lower_bound) | (x> upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# %%
outliers, cleaned = outliers_iqr_mod_log(sber_data, 'price_doc',True,3,3)
print(f'Число выбросов по методу Тьюки: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу Тьюки: 92
# Результирующее число записей: 30379

# %%
sber_data['id'].nunique() == sber_data.shape[0]
# Out:
# True

# %%
dupl_columns = list(sber_data.columns)
dupl_columns.remove('id')

mask = sber_data.duplicated(subset=dupl_columns)
sber_duplicates = sber_data[mask]
print(f'Число найденных дубликатов: {sber_duplicates.shape[0]}')
# Out:
# Число найденных дубликатов: 562

# %%
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30466    False
# 30467    False
# 30468    False
# 30469    False
# 30470    False
# Length: 30471, dtype: bool

# %%
sber_duplicates
# Out:
#           id  full_sq  life_sq  floor              sub_area  preschool_quota  \
# 257      258       44     20.0    8.0            Pechatniki           2936.0
# 443      444       44     27.0    1.0   Severnoe Medvedkovo           3916.0
# 472      473       22     14.0    9.0           Dmitrovskoe           1208.0
# 599      600       37     22.0    4.0           Bogorodskoe           3107.0
# 788      789       37     22.0    4.0           Bogorodskoe           3107.0
# ...      ...      ...      ...    ...                   ...              ...
# 30319  30322       39      NaN    6.0              Solncevo           3953.0
# 30322  30325       62      NaN    9.0  Poselenie Vnukovskoe              NaN
# 30388  30391       38     19.0    4.0            Nekrasovka           2395.0
# 30425  30428       64      NaN   13.0              Solncevo           3953.0
# 30447  30450       64      NaN   15.0              Solncevo           3953.0
#
#        preschool_education_centers_raion  school_quota  \
# 257                                    5        5791.0
# 443                                    4        7595.0
# 472                                    4        5671.0
# 599                                    7        7277.0
# 788                                    7        7277.0
# ...                                  ...           ...
# 30319                                  5        9700.0
# 30322                                  0           NaN
# 30388                                  5        7377.0
# 30425                                  5        9700.0
# 30447                                  5        9700.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 257                                 5                                      0
# 443                                 4                                      0
# 472                                 4                                      0
# 599                                 9                                      0
# 788                                 9                                      0
# ...                               ...                                    ...
# 30319                               5                                      0
# 30322                               0                                      0
# 30388                               5                                      0
# 30425                               5                                      0
# 30447                               5                                      0
#
#        ...  office_km  additional_education_km  preschool_km  big_church_km  \
# 257    ...   0.882085                 1.186001      0.422633       2.291423
# 443    ...   0.732302                 1.746865      0.291782       0.936937
# 472    ...   0.903281                 0.646299      0.157564       1.597722
# 599    ...   0.594123                 0.473285      0.055978       1.479723
# 788    ...   0.594123                 0.473285      0.055978       1.479723
# ...    ...        ...                      ...           ...            ...
# 30319  ...   1.052999                 0.509985      0.044599       3.407720
# 30322  ...   4.338453                 1.339078      1.234235       1.192543
# 30388  ...   5.003990                 1.687541      0.265093       3.206347
# 30425  ...   1.052999                 0.509985      0.044599       3.407720
# 30447  ...   1.052999                 0.509985      0.044599       3.407720
#
#        church_synagogue_km  theater_km  museum_km    ecology  \
# 257               0.686464    7.067698   3.776489  excellent
# 443               0.463655    7.252920   7.352771       good
# 472               1.259593   16.747885   8.065839       poor
# 599               0.724203    5.340694   5.006628       poor
# 788               0.724203    5.340694   5.006628       poor
# ...                    ...         ...        ...        ...
# 30319             2.002973    8.634607   4.896656       good
# 30322             1.186621   13.459593   9.890758    no data
# 30388             0.964153    8.630890   6.958959       good
# 30425             2.002973    8.634607   4.896656       good
# 30447             2.002973    8.634607   4.896656       good
#
#       mosque_count_1000 price_doc
# 257                   0   6200000
# 443                   0   6000000
# 472                   0   3500000
# 599                   0   6000000
# 788                   0   6000000
# ...                 ...       ...
# 30319                 0   4620233
# 30322                 0   7194232
# 30388                 0   3640798
# 30425                 0   6418251
# 30447                 0   6373324
#
# [562 rows x 61 columns]

# %%
sber_dedupped = sber_data.drop_duplicates(subset=dupl_columns)
print(f'Результирующее число записей: {sber_dedupped.shape[0]}')
# Out:
# Результирующее число записей: 29909

# %%
#список неинформативных признаков
low_information_cols = [] 

#цикл по всем столбцам
for col in sber_data.columns:
    #наибольшая относительная частота в признаке
    top_freq = sber_data[col].value_counts(normalize=True).max()
    #доля уникальных значений от размера признака
    nunique_ratio = sber_data[col].nunique() / sber_data[col].count()
    # сравниваем наибольшую частоту с порогом
    if top_freq > 0.95:
        low_information_cols.append(col)
        print(f'{col}: {round(top_freq*100, 2)}% одинаковых значений')
    # сравниваем долю уникальных значений с порогом
    if nunique_ratio > 0.95:
        low_information_cols.append(col)
        print(f'{col}: {round(nunique_ratio*100, 2)}% уникальных значений')
# Out:
# id: 100.0% уникальных значений
# oil_chemistry_raion: 99.03% одинаковых значений
# railroad_terminal_raion: 96.27% одинаковых значений
# nuclear_reactor_raion: 97.17% одинаковых значений
# big_road1_1line: 97.44% одинаковых значений
# mosque_count_1000: 98.08% одинаковых значений

# %%
low_information_cols
# Out:
# ['id',
#  'oil_chemistry_raion',
#  'railroad_terminal_raion',
#  'nuclear_reactor_raion',
#  'big_road1_1line',
#  'mosque_count_1000']

# %%
information_sber_data = sber_data.drop(low_information_cols, axis=1)
print(f'Результирующее число признаков: {information_sber_data.shape[1]}')
# Out:
# Результирующее число признаков: 55
